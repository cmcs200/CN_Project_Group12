# %%
import pandas as pd

# %%
df = pd.read_csv("yellow_tripdata_2016-03.csv")
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1               1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2               2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3               2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4               2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
# ...           ...                  ...                   ...              ...
# 2941813         2  2016-03-12 03:14:39   2016-03-12 03:31:18                1
# 2941814         2  2016-03-12 03:14:40   2016-03-12 03:23:14                1
# 2941815         2  2016-03-12 03:14:40   2016-03-12 03:20:56                1
# 2941816         2  2016-03-12 03:14:41   2016-03-12 03:20:19                2
# 2941817         2  2016-03-12 03:14:42   2016-03-12 03:34:27                1
#
# ...

# %%
df2 = df[["tpep_pickup_datetime", "tip_amount"]]

df2.to_csv("data_tpep_tipAmount.csv")

# %%
df3 = df[["payment_type", "total_amount","trip_distance"]]

df3.to_csv("data_payType_totalAmount_tripDistance.csv")

# %%
from google.colab import files
files.download('data_tpep_tipAmount.csv')

# %%
from google.colab import files
files.download('data_payType_totalAmount_tripDistance.csv')
